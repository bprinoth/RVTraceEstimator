# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('output (1).csv')
# Out:
#        phase     RV_RM  transit_sorted   RV_planet  RV_star     RV_tel
# 0   0.224738  2.694983               1  218.471086        0 -47.185681
# 1   0.227057  2.681002               1  218.957598        0 -47.191326
# 2   0.229377  2.666451               1  219.397594        0 -47.196957
# 3   0.231697  2.651334               1  219.790980        0 -47.202573
# 4   0.234017  2.635654               1  220.137672        0 -47.208172
# ..       ...       ...             ...         ...      ...        ...
# 95  0.445117 -0.424703               1   74.793301        0 -47.476591
# 96  0.447437 -0.465793               1   71.750417        0 -47.475940
# 97  0.449757 -0.506785               1   68.692290        0 -47.475212
# 98  0.452077 -0.547668               1   65.619569        0 -47.474408
# 99  0.454396 -0.588436               1   62.532908        0 -47.473529
#
# [100 rows x 6 columns]

# %%
# Out:
# ()
